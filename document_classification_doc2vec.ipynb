# %% [markdown]
# # Содержание:
#
#     1) Метод doc2vec с классификаторами:
#             1) Ridge Classifier
#             2) Perceptron
#             3) Passive Agressive
#             4) BeurnolliNB
#             5) MultinomialNB
#             6) KNeighbors
#             7) RandomForest
#             8) NearestCentroid
#             9) SGDClassifier
#             10) LinearSVC
#     2) Визуализация

# %%
# %matplotlib inline
import os
from lxml import etree
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectFromModel
from sklearn import preprocessing

# Author: Peter Prettenhofer <peter.prettenhofer@gmail.com>
#         Olivier Grisel <olivier.grisel@ensta.org>
#         Mathieu Blondel <mathieu@mblondel.org>
#         Lars Buitinck
# License: BSD 3 clause

from __future__ import print_function

import gensim
import logging
import numpy as np
from optparse import OptionParser
import sys
from time import time
import matplotlib.pyplot as plt
from nltk.util import ngrams
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.linear_model import RidgeClassifier
from sklearn.pipeline import Pipeline
from sklearn.svm import LinearSVC
from sklearn.linear_model import SGDClassifier
from sklearn.linear_model import Perceptron
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.naive_bayes import BernoulliNB, MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neighbors import NearestCentroid
from sklearn.ensemble import RandomForestClassifier
from sklearn.utils.extmath import density
from sklearn import metrics
from sklearn.linear_model import LogisticRegression
from collections import defaultdict
import pymorphy2

# Display progress logs on stdout
logging.basicConfig(level=logging.INFO,
                    format='%(asctime)s %(levelname)s %(message)s')

# %% [markdown]
# ## Подготовка текстов

# %%
class DocIterator(object):
    def __init__(self, doc_list, labels_list):
       self.labels_list = labels_list
       self.doc_list = doc_list
    def __iter__(self):
        for idx, doc in enumerate(self.doc_list):
            yield gensim.models.doc2vec.LabeledSentence(words=doc.split(),tags=[self.labels_list[idx]])

# %%
f = open('./out.csv', 'r')
cl = {'статья':0,'интервью':1,'комментарий':2}
file_hash = {}
for line in f:
    attrs = line.split(';')
    path = attrs[0]
    class_name = attrs[8]
    if ' ' in class_name:
        class_name = class_name.split()[0]
    if '|' in class_name:
        class_name = class_name.split('|')[0]
    filename = os.path.basename(path)
    if class_name in cl:
        file_hash[filename] = cl[class_name]

# %%
def check_len_of_classes():
    f = open('out.csv', 'r')
    dict_len = defaultdict(int)
    for line in f:
        attrs = line.split(';')
        path = attrs[0]
        class_name = attrs[8]
        dict_len[class_name] += 1
    return dict_len

# %%
#  check_len_of_classes()

# %%
morph = pymorphy2.MorphAnalyzer()
def normalize_and_add_pos(word):
    p = morph.parse(word)[0]
    return '{}_{}'.format(
        p.normal_form,
        p.tag.POS
    )
# Out:
# 2017-04-19 21:54:40,276 INFO Loading dictionaries from /Users/Valeriya/anaconda/lib/python3.5/site-packages/pymorphy2_dicts/data
# 2017-04-19 21:54:40,387 INFO format: 2.4, revision: 393442, updated: 2015-01-17T16:03:56.586168

# %%
def read_txt(path):
    for root, dirs, files in os.walk(path):
        for filename in files:
            open_name = os.path.join(root, filename)
            if filename in file_hash:
                class_text = file_hash[filename]
                tree = etree.parse(open_name)
                yield tree, class_text

# %%
sent = []
for tree, class_text in read_txt('/Users/Valeriya/Desktop/CoursePaper/corpus'):
    all_p = tree.xpath('//p')
    joined = '\n'.join([p.text for p in all_p if p.text is not None])
    sent.append((joined, class_text))

# %%
len(sent)
# Out:
# 1457

# %%
only_texts = [text[0] for text in sent]
classes = [text[1] for text in sent]

# %%
docLabels = [str(i) for i in range(2506)]

it = DocIterator(only_texts, docLabels)

model = gensim.models.Doc2Vec(window=10, min_count=5, workers=11,alpha=0.025, min_alpha=0.025) # use fixed learning rate
model.build_vocab(it)
for epoch in range(10):
    model.train(it)
    model.alpha -= 0.002 # decrease the learning rate
    model.min_alpha = model.alpha # fix the learning rate, no deca
    model.train(it)
# Out:
# 2017-04-19 21:55:29,282 INFO collecting all words and their counts
# 2017-04-19 21:55:29,284 INFO PROGRESS: at example #0, processed 0 words (0/s), 0 word types, 0 tags
# 2017-04-19 21:55:29,906 INFO collected 201513 word types and 1457 unique tags from a corpus of 1457 examples and 1222052 words
# 2017-04-19 21:55:29,907 INFO Loading a fresh vocabulary
# 2017-04-19 21:55:30,276 INFO min_count=5 retains 28281 unique words (14% of original 201513, drops 173232)
# 2017-04-19 21:55:30,277 INFO min_count=5 leaves 973617 word corpus (79% of original 1222052, drops 248435)
# 2017-04-19 21:55:30,380 INFO deleting the raw counts dictionary of 201513 items
# 2017-04-19 21:55:30,399 INFO sample=0.001 downsamples 30 most-common words
# 2017-04-19 21:55:30,400 INFO downsampling leaves estimated 839698 word corpus (86.2% of prior 973617)
# 2017-04-19 21:55:30,401 INFO estimated required memory for 28281 words and 100 dimensions: 37639500 bytes
# 2017-04-19 21:55:30,526 INFO resetting layer weights
# 2017-04-19 21:55:30,980 INFO training model with 11 workers on 28281 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=10
# 2017-04-19 21:55:30,981 INFO expecting 1457 sentences, matching count from corpus used for vocabulary survey
# 2017-04-19 21:55:32,016 INFO PROGRESS: at 11.17% examples, 390341 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:55:33,043 INFO PROGRESS: at 22.26% examples, 442656 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:55:34,051 INFO PROGRESS: at 33.12% examples, 445274 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:55:35,065 INFO PROGRESS: at 44.42% examples, 449050 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:55:36,066 INFO PROGRESS: at 55.54% examples, 458313 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:55:37,079 INFO PROGRESS: at 66.96% examples, 453560 words/s, in_qsize 22, out_qsize 0
# 2017-04-19 21:55:38,087 INFO PROGRESS: at 78.37% examples, 462068 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:55:39,097 INFO PROGRESS: at 91.17% examples, 464499 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:55:39,881 INFO worker thread finished; awaiting finish of 10 more threads
# 2017-04-19 21:55:39,883 INFO worker thread finished; awaiting finish of 9 more threads
# 2017-04-19 21:55:39,897 INFO worker thread finished; awaiting finish of 8 more threads
# 2017-04-19 21:55:39,898 INFO worker thread finished; awaiting finish of 7 more threads
# 2017-04-19 21:55:39,909 INFO worker thread finished; awaiting finish of 6 more threads
# 2017-04-19 21:55:39,919 INFO worker thread finished; awaiting finish of 5 more threads
# 2017-04-19 21:55:39,930 INFO worker thread finished; awaiting finish of 4 more threads
# 2017-04-19 21:55:39,972 INFO worker thread finished; awaiting finish of 3 more threads
# 2017-04-19 21:55:39,976 INFO worker thread finished; awaiting finish of 2 more threads
# 2017-04-19 21:55:39,981 INFO worker thread finished; awaiting finish of 1 more threads
# 2017-04-19 21:55:39,982 INFO worker thread finished; awaiting finish of 0 more threads
# 2017-04-19 21:55:39,983 INFO training on 6110260 raw words (4205839 effective words) took 9.0s, 467919 effective words/s
# 2017-04-19 21:55:39,984 INFO training model with 11 workers on 28281 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=10
# 2017-04-19 21:55:39,985 INFO expecting 1457 sentences, matching count from corpus used for vocabulary survey
# 2017-04-19 21:55:40,998 INFO PROGRESS: at 12.05% examples, 449426 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:55:42,014 INFO PROGRESS: at 22.44% examples, 452891 words/s, in_qsize 22, out_qsize 0
# 2017-04-19 21:55:43,024 INFO PROGRESS: at 33.66% examples, 458342 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:55:44,025 INFO PROGRESS: at 44.82% examples, 456723 words/s, in_qsize 22, out_qsize 0
# 2017-04-19 21:55:45,027 INFO PROGRESS: at 55.17% examples, 458754 words/s, in_qsize 22, out_qsize 0
# 2017-04-19 21:55:46,041 INFO PROGRESS: at 66.19% examples, 453187 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:55:47,051 INFO PROGRESS: at 76.88% examples, 457089 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:55:48,070 INFO PROGRESS: at 89.50% examples, 456076 words/s, in_qsize 22, out_qsize 0
# 2017-04-19 21:55:49,001 INFO worker thread finished; awaiting finish of 10 more threads
# 2017-04-19 21:55:49,025 INFO worker thread finished; awaiting finish of 9 more threads
# 2017-04-19 21:55:49,033 INFO worker thread finished; awaiting finish of 8 more threads
# 2017-04-19 21:55:49,037 INFO worker thread finished; awaiting finish of 7 more threads
# 2017-04-19 21:55:49,045 INFO worker thread finished; awaiting finish of 6 more threads
# 2017-04-19 21:55:49,062 INFO worker thread finished; awaiting finish of 5 more threads
# 2017-04-19 21:55:49,067 INFO worker thread finished; awaiting finish of 4 more threads
# 2017-04-19 21:55:49,090 INFO PROGRESS: at 99.53% examples, 460260 words/s, in_qsize 3, out_qsize 1
# 2017-04-19 21:55:49,093 INFO worker thread finished; awaiting finish of 3 more threads
# 2017-04-19 21:55:49,097 INFO worker thread finished; awaiting finish of 2 more threads
# 2017-04-19 21:55:49,098 INFO worker thread finished; awaiting finish of 1 more threads
# 2017-04-19 21:55:49,104 INFO worker thread finished; awaiting finish of 0 more threads
# 2017-04-19 21:55:49,105 INFO training on 6110260 raw words (4205553 effective words) took 9.1s, 461673 effective words/s
# 2017-04-19 21:55:49,106 INFO training model with 11 workers on 28281 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=10
# 2017-04-19 21:55:49,107 INFO expecting 1457 sentences, matching count from corpus used for vocabulary survey
# 2017-04-19 21:55:50,150 INFO PROGRESS: at 12.00% examples, 437567 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:55:51,150 INFO PROGRESS: at 22.06% examples, 443506 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:55:52,155 INFO PROGRESS: at 33.05% examples, 446776 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:55:53,165 INFO PROGRESS: at 44.10% examples, 448642 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:55:54,173 INFO PROGRESS: at 54.84% examples, 454207 words/s, in_qsize 22, out_qsize 0
# 2017-04-19 21:55:55,179 INFO PROGRESS: at 67.15% examples, 458526 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:55:56,179 INFO PROGRESS: at 77.10% examples, 457785 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:55:57,200 INFO PROGRESS: at 90.34% examples, 459752 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:55:58,037 INFO worker thread finished; awaiting finish of 10 more threads
# 2017-04-19 21:55:58,059 INFO worker thread finished; awaiting finish of 9 more threads
# 2017-04-19 21:55:58,080 INFO worker thread finished; awaiting finish of 8 more threads
# 2017-04-19 21:55:58,091 INFO worker thread finished; awaiting finish of 7 more threads
# 2017-04-19 21:55:58,098 INFO worker thread finished; awaiting finish of 6 more threads
# 2017-04-19 21:55:58,105 INFO worker thread finished; awaiting finish of 5 more threads
# 2017-04-19 21:55:58,118 INFO worker thread finished; awaiting finish of 4 more threads
# 2017-04-19 21:55:58,120 INFO worker thread finished; awaiting finish of 3 more threads
# 2017-04-19 21:55:58,142 INFO worker thread finished; awaiting finish of 2 more threads
# 2017-04-19 21:55:58,152 INFO worker thread finished; awaiting finish of 1 more threads
# 2017-04-19 21:55:58,157 INFO worker thread finished; awaiting finish of 0 more threads
# 2017-04-19 21:55:58,157 INFO training on 6110260 raw words (4205460 effective words) took 9.0s, 465417 effective words/s
# 2017-04-19 21:55:58,158 INFO training model with 11 workers on 28281 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=10
# 2017-04-19 21:55:58,159 INFO expecting 1457 sentences, matching count from corpus used for vocabulary survey
# 2017-04-19 21:55:59,195 INFO PROGRESS: at 11.57% examples, 411543 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:56:00,201 INFO PROGRESS: at 22.58% examples, 451274 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:56:01,201 INFO PROGRESS: at 34.23% examples, 469654 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:56:02,203 INFO PROGRESS: at 46.27% examples, 468618 words/s, in_qsize 22, out_qsize 0
# 2017-04-19 21:56:03,210 INFO PROGRESS: at 55.70% examples, 464661 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:56:04,227 INFO PROGRESS: at 68.52% examples, 463381 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:56:05,249 INFO PROGRESS: at 78.59% examples, 465094 words/s, in_qsize 22, out_qsize 0
# 2017-04-19 21:56:06,274 INFO PROGRESS: at 90.72% examples, 461625 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:56:07,284 INFO PROGRESS: at 98.64% examples, 454207 words/s, in_qsize 11, out_qsize 0
# 2017-04-19 21:56:07,292 INFO worker thread finished; awaiting finish of 10 more threads
# 2017-04-19 21:56:07,300 INFO worker thread finished; awaiting finish of 9 more threads
# 2017-04-19 21:56:07,304 INFO worker thread finished; awaiting finish of 8 more threads
# 2017-04-19 21:56:07,323 INFO worker thread finished; awaiting finish of 7 more threads
# 2017-04-19 21:56:07,333 INFO worker thread finished; awaiting finish of 6 more threads
# 2017-04-19 21:56:07,341 INFO worker thread finished; awaiting finish of 5 more threads
# 2017-04-19 21:56:07,359 INFO worker thread finished; awaiting finish of 4 more threads
# 2017-04-19 21:56:07,363 INFO worker thread finished; awaiting finish of 3 more threads
# 2017-04-19 21:56:07,373 INFO worker thread finished; awaiting finish of 2 more threads
# 2017-04-19 21:56:07,386 INFO worker thread finished; awaiting finish of 1 more threads
# 2017-04-19 21:56:07,390 INFO worker thread finished; awaiting finish of 0 more threads
# 2017-04-19 21:56:07,392 INFO training on 6110260 raw words (4205690 effective words) took 9.2s, 456386 effective words/s
# 2017-04-19 21:56:07,393 INFO training model with 11 workers on 28281 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=10
# 2017-04-19 21:56:07,394 INFO expecting 1457 sentences, matching count from corpus used for vocabulary survey
# 2017-04-19 21:56:08,453 INFO PROGRESS: at 6.93% examples, 208002 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:56:09,454 INFO PROGRESS: at 14.10% examples, 279312 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:56:10,458 INFO PROGRESS: at 24.97% examples, 329631 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:56:11,470 INFO PROGRESS: at 33.52% examples, 340028 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:56:12,491 INFO PROGRESS: at 40.05% examples, 330694 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:56:13,496 INFO PROGRESS: at 50.73% examples, 337581 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:56:14,502 INFO PROGRESS: at 58.37% examples, 344138 words/s, in_qsize 22, out_qsize 0
# 2017-04-19 21:56:15,503 INFO PROGRESS: at 71.08% examples, 360118 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:56:16,509 INFO PROGRESS: at 81.07% examples, 373166 words/s, in_qsize 20, out_qsize 1
# 2017-04-19 21:56:17,512 INFO PROGRESS: at 93.71% examples, 387650 words/s, in_qsize 22, out_qsize 1
# 2017-04-19 21:56:17,950 INFO worker thread finished; awaiting finish of 10 more threads
# 2017-04-19 21:56:17,954 INFO worker thread finished; awaiting finish of 9 more threads
# 2017-04-19 21:56:17,972 INFO worker thread finished; awaiting finish of 8 more threads
# 2017-04-19 21:56:17,985 INFO worker thread finished; awaiting finish of 7 more threads
# 2017-04-19 21:56:18,000 INFO worker thread finished; awaiting finish of 6 more threads
# 2017-04-19 21:56:18,006 INFO worker thread finished; awaiting finish of 5 more threads
# 2017-04-19 21:56:18,009 INFO worker thread finished; awaiting finish of 4 more threads
# 2017-04-19 21:56:18,011 INFO worker thread finished; awaiting finish of 3 more threads
# 2017-04-19 21:56:18,014 INFO worker thread finished; awaiting finish of 2 more threads
# 2017-04-19 21:56:18,025 INFO worker thread finished; awaiting finish of 1 more threads
# 2017-04-19 21:56:18,033 INFO worker thread finished; awaiting finish of 0 more threads
# 2017-04-19 21:56:18,033 INFO training on 6110260 raw words (4205399 effective words) took 10.6s, 395730 effective words/s
# 2017-04-19 21:56:18,034 INFO training model with 11 workers on 28281 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=10
# 2017-04-19 21:56:18,035 INFO expecting 1457 sentences, matching count from corpus used for vocabulary survey
# 2017-04-19 21:56:19,055 INFO PROGRESS: at 12.26% examples, 459324 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:56:20,061 INFO PROGRESS: at 23.31% examples, 467027 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:56:21,069 INFO PROGRESS: at 33.37% examples, 454980 words/s, in_qsize 19, out_qsize 2
# 2017-04-19 21:56:22,089 INFO PROGRESS: at 40.25% examples, 418024 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:56:23,106 INFO PROGRESS: at 50.38% examples, 402997 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:56:24,114 INFO PROGRESS: at 60.45% examples, 418200 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:56:25,119 INFO PROGRESS: at 72.51% examples, 425142 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:56:26,139 INFO PROGRESS: at 82.83% examples, 426576 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:56:27,172 INFO PROGRESS: at 94.84% examples, 435821 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:56:27,503 INFO worker thread finished; awaiting finish of 10 more threads
# 2017-04-19 21:56:27,513 INFO worker thread finished; awaiting finish of 9 more threads
# 2017-04-19 21:56:27,516 INFO worker thread finished; awaiting finish of 8 more threads
# 2017-04-19 21:56:27,524 INFO worker thread finished; awaiting finish of 7 more threads
# 2017-04-19 21:56:27,528 INFO worker thread finished; awaiting finish of 6 more threads
# 2017-04-19 21:56:27,535 INFO worker thread finished; awaiting finish of 5 more threads
# 2017-04-19 21:56:27,544 INFO worker thread finished; awaiting finish of 4 more threads
# 2017-04-19 21:56:27,545 INFO worker thread finished; awaiting finish of 3 more threads
# 2017-04-19 21:56:27,550 INFO worker thread finished; awaiting finish of 2 more threads
# 2017-04-19 21:56:27,557 INFO worker thread finished; awaiting finish of 1 more threads
# 2017-04-19 21:56:27,564 INFO worker thread finished; awaiting finish of 0 more threads
# 2017-04-19 21:56:27,565 INFO training on 6110260 raw words (4206683 effective words) took 9.5s, 441934 effective words/s
# 2017-04-19 21:56:27,565 INFO training model with 11 workers on 28281 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=10
# 2017-04-19 21:56:27,566 INFO expecting 1457 sentences, matching count from corpus used for vocabulary survey
# 2017-04-19 21:56:28,588 INFO PROGRESS: at 11.97% examples, 439785 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:56:29,599 INFO PROGRESS: at 22.53% examples, 451958 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:56:30,614 INFO PROGRESS: at 34.73% examples, 476326 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:56:31,630 INFO PROGRESS: at 48.24% examples, 484297 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:56:32,642 INFO PROGRESS: at 58.67% examples, 484686 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:56:33,643 INFO PROGRESS: at 71.79% examples, 488147 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:56:34,644 INFO PROGRESS: at 83.23% examples, 490338 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:56:35,656 INFO PROGRESS: at 94.45% examples, 489787 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:56:36,053 INFO worker thread finished; awaiting finish of 10 more threads
# 2017-04-19 21:56:36,062 INFO worker thread finished; awaiting finish of 9 more threads
# 2017-04-19 21:56:36,090 INFO worker thread finished; awaiting finish of 8 more threads
# 2017-04-19 21:56:36,100 INFO worker thread finished; awaiting finish of 7 more threads
# 2017-04-19 21:56:36,106 INFO worker thread finished; awaiting finish of 6 more threads
# 2017-04-19 21:56:36,111 INFO worker thread finished; awaiting finish of 5 more threads
# 2017-04-19 21:56:36,115 INFO worker thread finished; awaiting finish of 4 more threads
# 2017-04-19 21:56:36,121 INFO worker thread finished; awaiting finish of 3 more threads
# 2017-04-19 21:56:36,128 INFO worker thread finished; awaiting finish of 2 more threads
# 2017-04-19 21:56:36,129 INFO worker thread finished; awaiting finish of 1 more threads
# 2017-04-19 21:56:36,135 INFO worker thread finished; awaiting finish of 0 more threads
# 2017-04-19 21:56:36,136 INFO training on 6110260 raw words (4205733 effective words) took 8.6s, 491401 effective words/s
# 2017-04-19 21:56:36,136 INFO training model with 11 workers on 28281 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=10
# 2017-04-19 21:56:36,137 INFO expecting 1457 sentences, matching count from corpus used for vocabulary survey
# 2017-04-19 21:56:37,152 INFO PROGRESS: at 11.86% examples, 436051 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:56:38,162 INFO PROGRESS: at 22.47% examples, 454086 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:56:39,163 INFO PROGRESS: at 34.10% examples, 468815 words/s, in_qsize 22, out_qsize 0
# 2017-04-19 21:56:40,172 INFO PROGRESS: at 45.96% examples, 465863 words/s, in_qsize 20, out_qsize 1
# 2017-04-19 21:56:41,198 INFO PROGRESS: at 56.38% examples, 468378 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:56:42,221 INFO PROGRESS: at 69.46% examples, 466945 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:56:43,234 INFO PROGRESS: at 79.41% examples, 471259 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:56:44,237 INFO PROGRESS: at 91.81% examples, 469182 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:56:44,865 INFO worker thread finished; awaiting finish of 10 more threads
# 2017-04-19 21:56:44,886 INFO worker thread finished; awaiting finish of 9 more threads
# 2017-04-19 21:56:44,902 INFO worker thread finished; awaiting finish of 8 more threads
# 2017-04-19 21:56:44,908 INFO worker thread finished; awaiting finish of 7 more threads
# 2017-04-19 21:56:44,909 INFO worker thread finished; awaiting finish of 6 more threads
# 2017-04-19 21:56:44,933 INFO worker thread finished; awaiting finish of 5 more threads
# 2017-04-19 21:56:44,934 INFO worker thread finished; awaiting finish of 4 more threads
# 2017-04-19 21:56:44,945 INFO worker thread finished; awaiting finish of 3 more threads
# 2017-04-19 21:56:44,950 INFO worker thread finished; awaiting finish of 2 more threads
# 2017-04-19 21:56:44,952 INFO worker thread finished; awaiting finish of 1 more threads
# 2017-04-19 21:56:44,960 INFO worker thread finished; awaiting finish of 0 more threads
# 2017-04-19 21:56:44,960 INFO training on 6110260 raw words (4205650 effective words) took 8.8s, 477217 effective words/s
# 2017-04-19 21:56:44,961 INFO training model with 11 workers on 28281 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=10
# 2017-04-19 21:56:44,962 INFO expecting 1457 sentences, matching count from corpus used for vocabulary survey
# 2017-04-19 21:56:45,976 INFO PROGRESS: at 12.23% examples, 461724 words/s, in_qsize 20, out_qsize 1
# 2017-04-19 21:56:46,985 INFO PROGRESS: at 23.83% examples, 477705 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:56:47,986 INFO PROGRESS: at 34.89% examples, 484858 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:56:49,008 INFO PROGRESS: at 46.56% examples, 470876 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:56:50,014 INFO PROGRESS: at 56.75% examples, 471746 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:56:51,018 INFO PROGRESS: at 67.84% examples, 461790 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:56:52,021 INFO PROGRESS: at 77.10% examples, 458753 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:56:53,037 INFO PROGRESS: at 88.74% examples, 454343 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:56:53,963 INFO worker thread finished; awaiting finish of 10 more threads
# 2017-04-19 21:56:53,987 INFO worker thread finished; awaiting finish of 9 more threads
# 2017-04-19 21:56:53,994 INFO worker thread finished; awaiting finish of 8 more threads
# 2017-04-19 21:56:53,995 INFO worker thread finished; awaiting finish of 7 more threads
# 2017-04-19 21:56:54,002 INFO worker thread finished; awaiting finish of 6 more threads
# 2017-04-19 21:56:54,025 INFO worker thread finished; awaiting finish of 5 more threads
# 2017-04-19 21:56:54,031 INFO worker thread finished; awaiting finish of 4 more threads
# 2017-04-19 21
vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=10
# 2017-04-19 21:58:25,819 INFO expecting 1457 sentences, matching count from corpus used for vocabulary survey
# 2017-04-19 21:58:26,843 INFO PROGRESS: at 10.80% examples, 375033 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:58:27,868 INFO PROGRESS: at 22.07% examples, 441622 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:58:28,886 INFO PROGRESS: at 34.12% examples, 462455 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:58:29,894 INFO PROGRESS: at 46.73% examples, 471687 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:58:30,902 INFO PROGRESS: at 58.54% examples, 482696 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:58:31,904 INFO PROGRESS: at 71.08% examples, 479976 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:58:32,926 INFO PROGRESS: at 82.75% examples, 485264 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:58:33,953 INFO PROGRESS: at 95.00% examples, 490405 words/s, in_qsize 21, out_qsize 0
# 2017-04-19 21:58:34,221 INFO worker thread finished; awaiting finish of 10 more threads
# 2017-04-19 21:58:34,238 INFO worker thread finished; awaiting finish of 9 more threads
# 2017-04-19 21:58:34,245 INFO worker thread finished; awaiting finish of 8 more threads
# 2017-04-19 21:58:34,249 INFO worker thread finished; awaiting finish of 7 more threads
# 2017-04-19 21:58:34,259 INFO worker thread finished; awaiting finish of 6 more threads
# 2017-04-19 21:58:34,263 INFO worker thread finished; awaiting finish of 5 more threads
# 2017-04-19 21:58:34,268 INFO worker thread finished; awaiting finish of 4 more threads
# 2017-04-19 21:58:34,277 INFO worker thread finished; awaiting finish of 3 more threads
# 2017-04-19 21:58:34,286 INFO worker thread finished; awaiting finish of 2 more threads
# 2017-04-19 21:58:34,287 INFO worker thread finished; awaiting finish of 1 more threads
# 2017-04-19 21:58:34,293 INFO worker thread finished; awaiting finish of 0 more threads
# 2017-04-19 21:58:34,294 INFO training on 6110260 raw words (4205649 effective words) took 8.5s, 496904 effective words/s

# %%
X_train, X_test, y_train, y_test = train_test_split(list(model.docvecs), classes, test_size=0.3)

# %% [markdown]
# ## Классификация

# %%
categories = ['статья','интервью','комментарий']

print("Loading dataset for categories:")
print(categories if categories else "all")


print('data loaded')


def size_mb(docs):
    return sum(len(s.encode('utf-8')) for s in docs) / 1e6

print("Extracting features from the training data using a sparse vectorizer")
t0 = time()


duration = time() - t0


print("Extracting features from the test data using the same vectorizer")
t0 = time()


duration = time() - t0
# Out:
# Loading dataset for categories:
# ['статья', 'интервью', 'комментарий']
# data loaded
# Extracting features from the training data using a sparse vectorizer
# Extracting features from the test data using the same vectorizer

# %%
min_max_scaler = preprocessing.MinMaxScaler()
X_train_norm = min_max_scaler.fit_transform(X_train)
X_test_norm = min_max_scaler.fit_transform(X_test)

# %%
def benchmark(clf):
    print('_' * 80)
    print("Training: ")
    print(clf)
    t0 = time()
    if clf == MultinomialNB(alpha=.01):
        clf.fit(X_train, y_train)
    else:
        clf.fit(X_train_norm, y_train)
    train_time = time() - t0
    print("train time: %0.3fs" % train_time)

    t0 = time()
    if clf == MultinomialNB(alpha=.01):
        pred = clf.predict(X_test)
    else:
        pred = clf.predict(X_test_norm)
    test_time = time() - t0
    print("test time:  %0.3fs" % test_time)

    score = metrics.accuracy_score(y_test, pred)
    print("accuracy:   %0.3f" % score)

    print()
    clf_descr = str(clf).split('(')[0]
    return clf_descr, score, train_time, test_time


results = []
for clf, name in (
        (RidgeClassifier(tol=1e-2, solver="lsqr"), "Ridge Classifier"),
        (Perceptron(n_iter=50), "Perceptron"),
        (PassiveAggressiveClassifier(n_iter=50), "Passive-Aggressive"),
        (KNeighborsClassifier(n_neighbors=10), "kNN"),
        (RandomForestClassifier(n_estimators=100), "Random forest")):
    print('=' * 80)
    print(name)
    results.append(benchmark(clf))

for penalty in ["l2", "l1"]:
    print('=' * 80)
    print("%s penalty" % penalty.upper())
    # Train Liblinear model
    results.append(benchmark(LinearSVC(loss='l2', penalty=penalty,
                                            dual=False, tol=1e-3)))

    # Train SGD model
    results.append(benchmark(SGDClassifier(alpha=.0001, n_iter=50,
                                           penalty=penalty)))

# Train SGD with Elastic Net penalty
print('=' * 80)
print("Elastic-Net penalty")
results.append(benchmark(SGDClassifier(alpha=.0001, n_iter=50,
                                       penalty="elasticnet")))

# Train NearestCentroid without threshold
print('=' * 80)
print("NearestCentroid (aka Rocchio classifier)")
results.append(benchmark(NearestCentroid()))

# Train Logistic Regression
print('=' * 80)
print("Logistic Regression")
results.append(benchmark(LogisticRegression()))

# Train sparse Naive Bayes classifiers
print('=' * 80)
print("Naive Bayes")
results.append(benchmark(MultinomialNB(alpha=.01)))
results.append(benchmark(BernoulliNB(alpha=.01)))

print('=' * 80)
print("LinearSVC with L1-based feature selection")
# The smaller C, the stronger the regularization.
# The more regularization, the more sparsity.
results.append(benchmark(Pipeline([
  ('feature_selection', SelectFromModel(LinearSVC( penalty="l1", dual=False, tol=1e-3))),
  ('classification', LinearSVC())
])))

# make some plots

indices = np.arange(len(results))

results = [[x[i] for x in results] for i in range(4)]

clf_names, score, training_time, test_time = results
training_time = np.array(training_time) / np.max(training_time)
test_time = np.array(test_time) / np.max(test_time)
# Out:
# ================================================================================
# Ridge Classifier
# ________________________________________________________________________________
# Training:
# RidgeClassifier(alpha=1.0, class_weight=None, copy_X=True, fit_intercept=True,
#         max_iter=None, normalize=False, random_state=None, solver='lsqr',
#         tol=0.01)
# train time: 0.013s
# test time:  0.002s
# accuracy:   0.664
#
# ================================================================================
# Perceptron
# ________________________________________________________________________________
# Training:
# Perceptron(alpha=0.0001, class_weight=None, eta0=1.0, fit_intercept=True,
#       n_iter=50, n_jobs=1, penalty=None, random_state=0, shuffle=True,
#       verbose=0, warm_start=False)
# train time: 0.042s
# test time:  0.000s
# accuracy:   0.587
#
# ================================================================================
# Passive-Aggressive
# ________________________________________________________________________________
# Training:
# PassiveAggressiveClassifier(C=1.0, class_weight=None, fit_intercept=True,
#               loss='hinge', n_iter=50, n_jobs=1, random_state=None,
#               shuffle=True, verbose=0, warm_start=False)
# train time: 0.059s
# test time:  0.000s
# accuracy:   0.610
#
# ================================================================================
# kNN
# ________________________________________________________________________________
# Training:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=10, p=2,
#            weights='uniform')
# train time: 0.003s
# test time:  0.113s
# accuracy:   0.395
#
# ================================================================================
# Random forest
# ________________________________________________________________________________
# Training:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=100, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)
# train time: 0.746s
# test time:  0.017s
# accuracy:   0.559
#
# ================================================================================
# L2 penalty
# ________________________________________________________________________________
# Training:
# LinearSVC(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#      intercept_scaling=1, loss='l2', max_iter=1000, multi_class='ovr',
#      penalty='l2', random_state=None, tol=0.001, verbose=0)
# train time: 0.031s
# test time:  0.000s
# accuracy:   0.660
#
# ________________________________________________________________________________
# Training:
# SGDClassifier(alpha=0.0001, average=False, class_weight=None, epsilon=0.1,
#        eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='hinge', n_iter=50, n_jobs=1,
#        penalty='l2', power_t=0.5, random_state=None, shuffle=True,
#        verbose=0, warm_start=False)
# train time: 0.033s
# test time:  0.000s
# accuracy:   0.621
#
# ================================================================================
# L1 penalty
# ________________________________________________________________________________
# Training:
# LinearSVC(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#      intercept_scaling=1, loss='l2', max_iter=1000, multi_class='ovr',
#      penalty='l1', random_state=None, tol=0.001, verbose=0)
# /Users/Valeriya/anaconda/lib/python3.5/site-packages/sklearn/svm/classes.py:199: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# /Users/Valeriya/anaconda/lib/python3.5/site-packages/sklearn/svm/classes.py:199: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# train time: 0.432s
# test time:  0.001s
# accuracy:   0.660
#
# ________________________________________________________________________________
# Training:
# SGDClassifier(alpha=0.0001, average=False, class_weight=None, epsilon=0.1,
#        eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='hinge', n_iter=50, n_jobs=1,
#        penalty='l1', power_t=0.5, random_state=None, shuffle=True,
#        verbose=0, warm_start=False)
# train time: 0.081s
# test time:  0.000s
# accuracy:   0.614
#
# ================================================================================
# Elastic-Net penalty
# ________________________________________________________________________________
# Training:
# SGDClassifier(alpha=0.0001, average=False, class_weight=None, epsilon=0.1,
#        eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='hinge', n_iter=50, n_jobs=1,
#        penalty='elasticnet', power_t=0.5, random_state=None, shuffle=True,
#        verbose=0, warm_start=False)
# train time: 0.094s
# test time:  0.000s
# accuracy:   0.589
#
# ================================================================================
# NearestCentroid (aka Rocchio classifier)
# ________________________________________________________________________________
# Training:
# NearestCentroid(metric='euclidean', shrink_threshold=None)
# train time: 0.001s
# test time:  0.001s
# accuracy:   0.600
#
# ================================================================================
# Logistic Regression
# ________________________________________________________________________________
# Training:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)
# train time: 0.046s
# test time:  0.001s
# accuracy:   0.642
#
# ================================================================================
# Naive Bayes
# ________________________________________________________________________________
# Training:
# MultinomialNB(alpha=0.01, class_prior=None, fit_prior=True)
# train time: 0.002s
# test time:  0.000s
# accuracy:   0.420
#
# ________________________________________________________________________________
# Training:
# BernoulliNB(alpha=0.01, binarize=0.0, class_prior=None, fit_prior=True)
# train time: 0.002s
# test time:  0.001s
# accuracy:   0.393
#
# ================================================================================
# LinearSVC with L1-based feature selection
# ________________________________________________________________________________
# Training:
# Pipeline(steps=[('feature_selection', SelectFromModel(estimator=LinearSVC(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l1', random_state=None, tol=0.001,
#      verbose=0),
#         prefit=False, thresho...ax_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#      verbose=0))])
# train time: 1.085s
# test time:  0.001s
# accuracy:   0.660

# %% [markdown]
# ## Визуализация

# %%
scores = results[1]
cls_names = results[0]

plt.figure(figsize=(12, 8))
plt.title("Score")
plt.barh(indices, scores, .2, label="score", color='navy')
plt.yticks(())
plt.legend(loc='best')
plt.subplots_adjust(left=.25)
plt.subplots_adjust(top=1)
plt.subplots_adjust(bottom=.05)

for i, c in zip(indices, results[0]):
    plt.text(-.3, i, c)
plt.show()
